# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load and read dataset
data = pd.read_csv('/content/poverty.csv')
data.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 1  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 2  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 3  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 4  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
#determine the location of the dataset 
data=data.iloc[4:]

# %%
#location of the year data set
data_year=data.iloc[:,4:]

# %%
#read the data of the year
data_year.head()
# Out:
#     1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2012  \
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.2
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.9
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#     2013  2014  2015  2016  2017  2018  2019  2020  2021
# 8    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN
# 9    1.0   0.9   NaN   1.1   0.9   1.4   1.3   1.6   NaN
# 10   1.8   1.5   1.3   1.2   0.9   1.4   1.1   0.4   NaN
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 62 columns]

# %%
#poverty data per year
data_year_poverty=pd.DataFrame(data_year)
data_year_poverty
# Out:
#      1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2012  \
# 8     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 9     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.2
# 10    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.9
# 11    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 12    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.6
# 266   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 267   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 268   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 269   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#      2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
#sum of the years for better results
data_year=data_year.sum(axis=0)
data_year
# Out:
# 1960      0.0
# 1961      0.0
# 1962      0.0
# 1963      0.0
# 1964      0.0
#         ...
# 2017    468.9
# 2018    644.3
# 2019    302.9
# 2020     44.6
# 2021      2.2
# Length: 62, dtype: float64

# %%
#plot the year poverty graph 
plt.figure(figsize=(10,10))
plt.plot(data_year_poverty)
plt.title('Poverty per year')
plt.xlabel('Povery rate')
plt.ylabel('Povery rate')
# Out:
# Text(0, 0.5, 'Povery rate')

# %%
#data type change
data_year_poverty['year']=data_year_poverty.index.astype('int')
data_year_poverty
# Out:
#      1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2013  \
# 8     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.0
# 9     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0
# 10    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.8
# 11    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 12    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 265   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.3
# 266   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 267   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 268   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 269   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#      2014  2015  2016  2017  2018  2019  2020  2021  year
# ...

# %%
#read the data type
data_year_poverty.dtypes
# Out:
# 1960    float64
# 1961    float64
# 1962    float64
# 1963    float64
# 1964    float64
#          ...
# 2018    float64
# 2019    float64
# 2020    float64
# 2021    float64
# year      int64
# Length: 63, dtype: object

# %%
#selecting the columns of the country name and code and years
country_data=data[['Country Name','Country Code','2000','2010']]

# %%
#read
country_data
# Out:
#              Country Name Country Code  2000  2010
# 8    United Arab Emirates          ARE   NaN   NaN
# 9               Argentina          ARG   6.8   1.4
# 10                Armenia          ARM   NaN   1.0
# 11         American Samoa          ASM   NaN   NaN
# 12    Antigua and Barbuda          ATG   NaN   NaN
# ..                    ...          ...   ...   ...
# 265              Zimbabwe          ZWE   NaN   2.5
# 266                   NaN          NaN   NaN   NaN
# 267                   NaN          NaN  34.8  16.2
# 268                   NaN          NaN   NaN  65.8
# 269                   NaN          NaN   NaN   NaN
#
# [262 rows x 4 columns]

# %%
#max poverty recored in 2010
country_data['2010'].max()
# Out:
# 78.2

# %%
#country having the highest poverty in 2010
country_data.loc[country_data['2010']>65]
# Out:
#       Country Name Country Code  2000  2010
# 87   Guinea-Bissau          GNB   NaN  68.4
# 151     Madagascar          MDG   NaN  78.2
# 168         Malawi          MWI   NaN  71.1
# 268            NaN          NaN   NaN  65.8

# %%
#selected country
code_country=['MDG','MWI','RWA','GNB']

# %%
#selection for ploting
country_year=country_data[country_data['Country Code'].isin(code_country)]

# %%
#plotting country name
plt.bar(country_year['Country Name'],country_year['2010'],color='blue')
# Out:
# <BarContainer object of 4 artists>

# %%
#max poverty recored in 2000
country_data['2000'].max()
# Out:
# 86.2

# %%
#country having the highest poverty in 2000
country_data.loc[country_data['2000']>50]
# Out:
#               Country Name Country Code  2000  2010
# 104              IDA total          IDA  50.4  34.1
# 136             Low income          LIC  60.3  48.7
# 203                 Rwanda          RWA  78.0  63.2
# 217     Sub-Saharan Africa          SSF  57.8  45.3
# 246               Tanzania          TZA  86.2   NaN
# 256  Virgin Islands (U.S.)          VIR  61.5   NaN

# %%
#selected country
code_country=['VIR','IDA','RWA','SSF','TZA']

# %%
#selection for ploting
country_year=country_data[country_data['Country Code'].isin(code_country)]

# %%
#plotting country name
plt.bar(country_year['Country Name'],country_year['2000'],color='red')
# Out:
# <BarContainer object of 5 artists>
